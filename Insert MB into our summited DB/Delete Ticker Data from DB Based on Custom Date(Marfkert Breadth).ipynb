# %%
# Load reqiured package :
import pandas as pd
import cx_Oracle
import datetime
import csv
import time
import sys
#--------------------------------------------------------------------------------
#--------------------------------------------------------------------------------
# DB Connection
def dbConnect():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    return con


con2 = dbConnect()
#--------------------------------------------------------------------------------
#--------------------------------------------------------------------------------
# delete ticker custom data based on custom datetime
# date if  == 2024,8,11 delete that day and more
# must set the date we need to remove 
sql2 ='delete from  STOCK.FILL_OHLCV OPEN where Ticker = :1 AND BARTIMESTAMP > :2'
# that remove all  date and more y m d
tickersadjustlis = ["EGX30LASTEWIMB"]
for tick in tickersadjustlis :
    param2  = [tick,datetime.datetime(2025,4,27,0,0)]
    cursor4 = con2.cursor()
    cursor4.execute(sql2,param2)
    con2.commit()
    print(f" Update {tick} done")
# Out:
# 11.2.0.4.0
#  Update EGX30LASTEWIMB done
